# %%
## ⛔ Thing to keep in mind
'''
- **The use of ChatGPT (or similar tools), however, google use is allowed**
- You are required to keep your camera on and share your entire screen  throughout the challenge.
- Once you complete the challenge, please call us at 7974170622  to assist you with the next part.
- Once you are done, push your project to a GitHub repository and make it private. Give access to [sameer@theproven.club](mailto:sameer@theproven.club) and [saurabh@theproven.club](mailto:saurabh@theproven.club) and share the link with us.

## ⌛ Max time: 1.5 hours

# 📜 Asks

## 🖊️ Task 1:

### 1️⃣: **Load the Provided Imbalanced Dataset**

- [Load the provided dataset.](https://drive.google.com/file/d/1znfLVysX_sC7ZVzaWz7oUZAI21j6Ifbc/view?usp=sharing)
- Perform basic exploratory data analysis (EDA) to understand the data distribution.

### 2️⃣: **Address the Imbalance**

- Analyze the imbalance in the dataset.
- Implement techniques to address the imbalance (e.g., resampling methods like SMOTE, ADASYN, or undersampling)

### 3️⃣: **Model Training and Evaluation**

- Split the data into training, validation, and testing sets using an appropriate strategy.
- Train a machine learning model on the dataset. (e.g., Random Forest, SVM)
- Evaluate the model using appropriate metrics, focusing on handling imbalanced data. (e.g., precision, recall, F1-score, ROC-AUC)

### 4️⃣: **Report and Discussion**

- Explain the methodology used to address the imbalance.
- Discuss the train-test-validation splitting strategy.
- Justify the choice of metrics for evaluating the model performance.

## 🖊️ Task 2:

### 1️⃣: **Load the Provided Imbalanced Dataset**

- [Load the provided dataset.](https://drive.google.com/file/d/16PeRPGO4AsPNWNqPTEzTLcngMqldpt1T/view?usp=sharing)
- Perform basic exploratory data analysis (EDA) to understand the data distribution.

### 2️⃣: **Implement Feature Selection Techniques**

- Analyze the dataset to identify relevant features.
- Implement feature selection techniques such as mutual information, recursive feature elimination, or principal component analysis (PCA).

### 3️⃣: **Model Training and Evaluation**

- Train a classifier (e.g., Logistic Regression, Decision Tree) on the dataset with all features.
- Train a classifier on the dataset with selected features.
- Evaluate and compare the model performance using appropriate metrics (e.g., accuracy, precision, recall, F1-score).

### 4️⃣: **Report and Discussion**

- Explain the methodology used for feature selection.
- Compare the model performance before and after feature selection.
- Discuss the impact of feature selection on the model performance.
'''
# Out:
# '\n- **The use of ChatGPT (or similar tools), however, google use is allowed**\n- You are required to keep your camera on and share your entire screen  throughout the challenge.\n- Once you complete the challenge, please call us at 7974170622  to assist you with the next part.\n- Once you are done, push your project to a GitHub repository and make it private. Give access to [sameer@theproven.club](mailto:sameer@theproven.club) and [saurabh@theproven.club](mailto:saurabh@theproven.club) and share the link with us.\n\n## ⌛ Max time: 1.5 hours\n\n# 📜\xa0Asks\n\n## 🖊️ Task 1:\n\n### 1️⃣: **Load the Provided Imbalanced Dataset**\n\n- [Load the provided dataset.](https://drive.google.com/file/d/1znfLVysX_sC7ZVzaWz7oUZAI21j6Ifbc/view?usp=sharing)\n- Perform basic exploratory data analysis (EDA) to understand the data distribution.\n\n### 2️⃣: **Address the Imbalance**\n\n- Analyze the imbalance in the dataset.\n- Implement techniques to address the imbalance (e.g., resampling methods like S
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Data.csv')

# %%
df.head(10)
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   0.477908  -0.913100  -0.142257  -0.888393   0.101232   0.557124
# 1  -0.307475  -0.097225   0.936320   0.642466   1.165698  -0.399368
# 2   1.047926   1.403379  -0.488940  -1.913669  -0.082735   1.201800
# 3  -0.249407  -0.431734   1.639818   0.195003   1.070736  -0.135673
# 4   0.049466   0.530635  -2.463684  -0.006239   0.735609   0.008183
# 5   0.238868   0.636137   0.370479  -0.586453   1.461004   0.360678
# 6   0.126730  -0.853253  -0.386327  -0.196253   1.906262   0.125032
# 7  -0.396597  -1.693236   0.561274   0.707836  -1.249340  -0.445359
# 8   1.906658  -1.274729  -1.275694  -3.079229   0.087067   1.954202
# 9   0.900578  -1.205586  -0.580489  -1.186680  -0.580808   0.768469
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_12  feature_13  \
# 0   0.603857   0.392627  -0.068788   -0.421507  ...   -0.151552    0.489513
# ...

# %% [markdown]
# ## EDA:

# %%
df.columns
# Out:
# Index(['feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5',
#        'feature_6', 'feature_7', 'feature_8', 'feature_9', 'feature_10',
#        'feature_11', 'feature_12', 'feature_13', 'feature_14', 'feature_15',
#        'feature_16', 'feature_17', 'feature_18', 'feature_19', 'feature_20',
#        'target'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# feature_1     0
# feature_2     0
# feature_3     0
# feature_4     0
# feature_5     0
# feature_6     0
# feature_7     0
# feature_8     0
# feature_9     0
# feature_10    0
# feature_11    0
# feature_12    0
# feature_13    0
# feature_14    0
# feature_15    0
# feature_16    0
# feature_17    0
# feature_18    0
# feature_19    0
# feature_20    0
# target        0
# dtype: int64

# %%
len(df.columns)
# Out:
# 21

# %%
df['target'].value_counts()
# Out:
# target
# 0    9900
# 1     100
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (10000, 21)

# %%
from sklearn.model_selection import train_test_split

X =df.drop(['target'],axis = 1)
print(X.shape)
y= df['target']
x_train,x_test, y_train,y_test = train_test_split(X,y, test_size = 0.3,random_state=42,stratify = y)
# Out:
# (10000, 20)

# %%
x_test.shape
# Out:
# (3000, 20)

# %%
y_test.value_counts()
# Out:
# target
# 0    2970
# 1      30
# Name: count, dtype: int64

# %% [markdown]
# ## Class - Distribution

# %%
y_train.value_counts()
# Out:
# target
# 0    6930
# 1      70
# Name: count, dtype: int64

# %% [markdown]
# ## SMOTE technique to handle Imbalance

# %%
import imblearn
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(x_train, y_train)

# %%
y_res.value_counts()
# Out:
# target
# 0    6930
# 1    6930
# Name: count, dtype: int64

# %% [markdown]
# ## Model Creation: Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier( random_state=42)
clf.fit(X_res, y_res)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import roc_curve
import sklearn.metrics as metrics

import matplotlib.pyplot as plt

fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.9983333333333333
# Precision : 0.8787878787878788
# Recall : 0.9666666666666667
# F1-score : 0.9206349206349207

# %% [markdown]
# ## Feature Importances:

# %%
import numpy as np
importances = clf.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf.estimators_], axis=0)
forest_importances = pd.Series(importances, index=x_train.columns)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
forest_importances
# Out:
# feature_1     0.045347
# feature_2     0.000682
# feature_3     0.001276
# feature_4     0.105876
# feature_5     0.000734
# feature_6     0.074648
# feature_7     0.006536
# feature_8     0.000839
# feature_9     0.008604
# feature_10    0.006908
# feature_11    0.000927
# feature_12    0.186043
# feature_13    0.019716
# feature_14    0.146042
# feature_15    0.000830
# feature_16    0.000332
# feature_17    0.239893
# feature_18    0.137296
# feature_19    0.016946
# feature_20    0.000524
# dtype: float64

# %% [markdown]
# # scores above 0.05

# %%
imp_features = [ 'feature_4','feature_6','feature_12','feature_14','feature_17','feature_18']

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier( random_state=42)
X_res_imp = X_res[imp_features]
clf.fit(X_res_imp, y_res)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = clf.predict(x_test[imp_features])

# %%
from sklearn.metrics import roc_curve
import sklearn.metrics as metrics

import matplotlib.pyplot as plt

fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.996
# Precision : 0.725
# Recall : 0.9666666666666667
# F1-score : 0.8285714285714285

# %% [markdown]
# ## Dimenionionality - Reduction Applying: PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=4)
pca_X = pca.fit_transform(X_res)
X_res = pd.DataFrame(data = pca_X , columns = ['PCA_1', 'PCA_2','PCA_3','PCA_4'])

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier( random_state=42)
clf.fit(X_res, y_res)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=4)
pca_X = pca.fit_transform(x_test)
X_res_test = pd.DataFrame(data = pca_X , columns = ['PCA_1', 'PCA_2','PCA_3','PCA_4'])

# %%
y_pred = clf.predict(X_res_test)

# %%
from sklearn.metrics import roc_curve
import sklearn.metrics as metrics

import matplotlib.pyplot as plt

fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.7023333333333334
# Precision : 0.02841530054644809
# Recall : 0.8666666666666667
# F1-score : 0.05502645502645503

# %%
forest_importances
# Out:
# feature_1     0.045347
# feature_2     0.000682
# feature_3     0.001276
# feature_4     0.105876
# feature_5     0.000734
# feature_6     0.074648
# feature_7     0.006536
# feature_8     0.000839
# feature_9     0.008604
# feature_10    0.006908
# feature_11    0.000927
# feature_12    0.186043
# feature_13    0.019716
# feature_14    0.146042
# feature_15    0.000830
# feature_16    0.000332
# feature_17    0.239893
# feature_18    0.137296
# feature_19    0.016946
# feature_20    0.000524
# dtype: float64

# %%
import numpy as np
importances = clf.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf.estimators_], axis=0)
forest_importances = pd.Series(importances, index=X_res.columns)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# # Weighted Class approach to handle imbalance Data

# %%
clf = RandomForestClassifier(class_weight={0:.01, 1:.99})
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(class_weight={0: 0.01, 1: 0.99})

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import roc_curve
import sklearn.metrics as metrics

import matplotlib.pyplot as plt

fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.999
# Precision : 0.9354838709677419
# Recall : 0.9666666666666667
# F1-score : 0.9508196721311476

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.999
# Precision : 0.9354838709677419
# Recall : 0.9666666666666667
# F1-score : 0.9508196721311476

# %% [markdown]
# ## Feature Importances

# %%
import numpy as np
importances = clf.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf.estimators_], axis=0)
forest_importances = pd.Series(importances, index=x_train.columns)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
forest_importances
# Out:
# feature_1     0.028237
# feature_2     0.000518
# feature_3     0.001180
# feature_4     0.155409
# feature_5     0.000998
# feature_6     0.104699
# feature_7     0.014802
# feature_8     0.000091
# feature_9     0.009428
# feature_10    0.004459
# feature_11    0.000588
# feature_12    0.105222
# feature_13    0.018984
# feature_14    0.201681
# feature_15    0.000622
# feature_16    0.000409
# feature_17    0.261904
# feature_18    0.068616
# feature_19    0.021370
# feature_20    0.000785
# dtype: float64

# %%
imp_features = [ 'feature_1','feature_4','feature_6','feature_12','feature_14','feature_17','feature_18','feature_13']

# %% [markdown]
# ## Model Creation with important features

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(class_weight={0:.01, 1:.99})
x_train_imp = x_train[imp_features]
clf.fit(x_train_imp, y_train)
# Out:
# RandomForestClassifier(class_weight={0: 0.01, 1: 0.99})

# %%
y_pred = clf.predict(x_test[imp_features])

# %%
from sklearn.metrics import roc_curve
import sklearn.metrics as metrics

import matplotlib.pyplot as plt

fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.999
# Precision : 0.9354838709677419
# Recall : 0.9666666666666667
# F1-score : 0.9508196721311476

# %% [markdown]
# ## Applying PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=4)
pca_X = pca.fit_transform(x_train)
X_res = pd.DataFrame(data = pca_X , columns = ['PCA_1', 'PCA_2','PCA_3','PCA_4'])

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier( random_state=42)
clf.fit(X_res, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=4)
pca_X = pca.fit_transform(x_test)
X_res_test = pd.DataFrame(data = pca_X , columns = ['PCA_1', 'PCA_2','PCA_3','PCA_4'])

# %%
y_pred = clf.predict(X_res_test)

# %%
from sklearn.metrics import roc_curve
import sklearn.metrics as metrics

import matplotlib.pyplot as plt

fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.99
# Precision : 0.0
# Recall : 0.0
# F1-score : 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import numpy as np
importances = clf.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf.estimators_], axis=0)
forest_importances = pd.Series(importances, index=X_res.columns)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
forest_importances
# Out:
# PCA_1    0.307170
# PCA_2    0.231836
# PCA_3    0.228564
# PCA_4    0.232430
# dtype: float64

# %% [markdown]
# # Applying XGBoost Classifier

# %%
import imblearn
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(x_train, y_train)

# %%
import xgboost
from xgboost import XGBClassifier

clf = XGBClassifier(random_state=42)

# %%
clf.fit(X_res, y_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import roc_curve
import sklearn.metrics as metrics

import matplotlib.pyplot as plt

fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.998
# Precision : 0.8529411764705882
# Recall : 0.9666666666666667
# F1-score : 0.90625

# %% [markdown]
# ## Feature Importances:

# %%
clf.feature_importances_
# Out:
# array([1.0330359e-03, 7.5182458e-04, 3.8728507e-03, 2.3952143e-02,
#        2.5146552e-03, 1.7233783e-02, 1.0608414e-03, 1.2648964e-03,
#        4.8708640e-02, 7.7235681e-04, 5.0569726e-03, 1.2483696e-03,
#        1.4200923e-03, 1.7663471e-02, 1.0086221e-03, 9.6768350e-04,
#        8.5536987e-01, 9.0739457e-03, 6.9476194e-03, 7.8299156e-05],
#       dtype=float32)

# %%
plt.bar(range(len(clf.feature_importances_)), clf.feature_importances_)
plt.show()

# %% [markdown]
# # scores above 0.05

# %%
imp_features = [ 'feature_4','feature_6','feature_12','feature_14','feature_17','feature_18','feature_9']

# %%
import xgboost
from xgboost import XGBClassifier

clf = XGBClassifier(random_state=42)

X_res_imp = X_res[imp_features]
clf.fit(X_res_imp, y_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = clf.predict(x_test[imp_features])

# %%
from sklearn.metrics import roc_curve
import sklearn.metrics as metrics

import matplotlib.pyplot as plt

fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.9966666666666667
# Precision : 0.7631578947368421
# Recall : 0.9666666666666667
# F1-score : 0.8529411764705883

# %% [markdown]
# ## Dimenionionality - Reduction Applying: PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=4)
pca_X = pca.fit_transform(X_res)
X_res = pd.DataFrame(data = pca_X , columns = ['PCA_1', 'PCA_2','PCA_3','PCA_4'])

# %%
import xgboost
from xgboost import XGBClassifier

clf = XGBClassifier(random_state=42)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=4)
pca_X = pca.fit_transform(x_test)
X_res_test = pd.DataFrame(data = pca_X , columns = ['PCA_1', 'PCA_2','PCA_3','PCA_4'])

# %%
clf.fit(X_res_test,y_test)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = clf.predict(X_res_test)

# %%
from sklearn.metrics import roc_curve
import sklearn.metrics as metrics

import matplotlib.pyplot as plt

fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 1.0
# Precision : 1.0
# Recall : 1.0
# F1-score : 1.0

# %%
plt.bar(range(len(clf.feature_importances_)), clf.feature_importances_)
plt.show()

# %% [markdown]
# # Weighted Class approach to handle imbalance Data

# %%
import xgboost
from xgboost import XGBClassifier

clf = XGBClassifier(class_weight={0:.01, 1:.99},random_state=42)

# %%
clf.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [10:22:45] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "class_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               class_weight={0: 0.01, 1: 0.99}, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import roc_curve
import sklearn.metrics as metrics

import matplotlib.pyplot as plt

fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.999
# Precision : 0.9354838709677419
# Recall : 0.9666666666666667
# F1-score : 0.9508196721311476

# %% [markdown]
# ## Feature Importances

# %%
plt.bar(range(len(clf.feature_importances_)), clf.feature_importances_)
plt.show()

# %%
forest_importances
# Out:
# feature_1     0.028237
# feature_2     0.000518
# feature_3     0.001180
# feature_4     0.155409
# feature_5     0.000998
# feature_6     0.104699
# feature_7     0.014802
# feature_8     0.000091
# feature_9     0.009428
# feature_10    0.004459
# feature_11    0.000588
# feature_12    0.105222
# feature_13    0.018984
# feature_14    0.201681
# feature_15    0.000622
# feature_16    0.000409
# feature_17    0.261904
# feature_18    0.068616
# feature_19    0.021370
# feature_20    0.000785
# dtype: float64

# %%
imp_features = [ 'feature_1','feature_4','feature_6','feature_12','feature_14','feature_17','feature_18','feature_13']

# %% [markdown]
# ## Model Creation with important features

# %%
import xgboost
from xgboost import XGBClassifier

clf = XGBClassifier(class_weight={0:.01, 1:.99},random_state=42)
x_train_imp = x_train[imp_features]
clf.fit(x_train_imp, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [10:23:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "class_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               class_weight={0: 0.01, 1: 0.99}, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %%
y_pred = clf.predict(x_test[imp_features])

# %%
from sklearn.metrics import roc_curve
import sklearn.metrics as metrics

import matplotlib.pyplot as plt

fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.9986666666666667
# Precision : 0.90625
# Recall : 0.9666666666666667
# F1-score : 0.9354838709677419

# %% [markdown]
# ## Applying PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=4)
pca_X = pca.fit_transform(x_train)
X_res = pd.DataFrame(data = pca_X , columns = ['PCA_1', 'PCA_2','PCA_3','PCA_4'])

# %%
import xgboost
from xgboost import XGBClassifier

clf = XGBClassifier(class_weight={0:.01, 1:.99},random_state=42)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=4)
pca_X = pca.fit_transform(x_test)
X_res_test = pd.DataFrame(data = pca_X , columns = ['PCA_1', 'PCA_2','PCA_3','PCA_4'])

# %%
clf.fit(X_res,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [10:25:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "class_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               class_weight={0: 0.01, 1: 0.99}, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %%
y_pred = clf.predict(X_res_test)

# %%
from sklearn.metrics import roc_curve
import sklearn.metrics as metrics

import matplotlib.pyplot as plt

fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.9893333333333333
# Precision : 0.0
# Recall : 0.0
# F1-score : 0.0

# %%
plt.bar(range(len(clf.feature_importances_)), clf.feature_importances_)
plt.show()

# %%
clf.feature_importances_
# Out:
# array([0.4646778 , 0.19775464, 0.17618385, 0.1613837 ], dtype=float32)
